# %% [markdown]
# # Decode trajectory viewer
#
# Load one JSONL record from `python -m doublebackprop.dump_decode_trajectories` (field `trajectory`: list of token-id vectors per step). Use the slider to scrub through decoding; optionally export a GIF with `matplotlib.animation`.
#
# For Sudoku / n-queens, `doublebackprop.viz_puzzle_state` maps ids to a small grid for `imshow`.

# %%
from pathlib import Path
import json
import sys

# Ensure repo root is on path (notebook may run with cwd = plotting_scripts/ or project root)
_here = Path.cwd()
if (_here / "doublebackprop" / "viz_puzzle_state.py").is_file():
    _root = _here
elif (_here.parent / "doublebackprop" / "viz_puzzle_state.py").is_file():
    _root = _here.parent
else:
    _root = _here  # last resort; may still fail if cwd is elsewhere
if str(_root) not in sys.path:
    sys.path.insert(0, str(_root))

import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as w
from IPython.display import display

from doublebackprop.viz_puzzle_state import (
    sudoku_ids_to_grid,
    n_queens_ids_to_grid,
    infer_dataset,
)

JSONL = Path("../decode_trajectories.jsonl")  # set path to your dump
LINE_INDEX = 0  # which example line to visualize

lines = JSONL.read_text().strip().splitlines()
rec = json.loads(lines[LINE_INDEX])
traj = rec["trajectory"]
tags = rec.get("tags") or {}
ds = infer_dataset(tags)
print("dataset:", ds, "steps:", len(traj))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 21
#      18 import ipywidgets as w
#      19 from IPython.display import display
# ---> 21 from doublebackprop.viz_puzzle_state import (
#      22     sudoku_ids_to_grid,
#      23     n_queens_ids_to_grid,
#      24     infer_dataset,
#      25 )
#      27 JSONL = Path("../decode_trajectories.jsonl")  # set path to your dump
#      28 LINE_INDEX = 0  # which example line to visualize
#
# File /work/pi_mccallum_umass_edu/brozonoyer_umass_edu/double-backprop/doublebackprop/__init__.py:15
#       1 """
#       2 Double Backprop - Imitation Learning for XLM Framework
#       3
#    (...)     11 - History tracking (history.py)
#      12 """
#      14 from .model import RotaryTransformerModel, RotaryTransformerLoopholingModel
# ---> 15 from .loss import MLMLoss, LoopholingBPTTPumaLoss, PumaLoss
#      16 from .streaming_batch import StreamingBatch
#      17 from .predictor import ConfidenceBasedPredictor
#
# ImportError: cannot import name 'PumaLoss' from 'doublebackprop.loss' (/work/pi_mccallum_umass_edu/brozonoyer_umass_edu/double-backprop/doublebackprop/loss.py)

# %%
def ids_to_grid(step_ids):
    if "sudoku" in ds.lower():
        return sudoku_ids_to_grid(step_ids)
    if "queens" in ds.lower() or "n_queens" in ds.lower():
        return n_queens_ids_to_grid(step_ids)
    return np.array(step_ids, dtype=np.float32)

fig, ax = plt.subplots(figsize=(4, 4))
im = ax.imshow(ids_to_grid(traj[0]), vmin=-1, vmax=10, cmap="viridis")
ax.set_title(f"step 0 / {len(traj)-1}")
plt.colorbar(im, ax=ax)

def update(step):
    step = int(step)
    g = ids_to_grid(traj[step])
    im.set_data(g)
    ax.set_title(f"step {step} / {len(traj)-1}")
    fig.canvas.draw_idle()

slider = w.IntSlider(value=0, min=0, max=len(traj) - 1, step=1, description="step")
w.interact(update, step=slider)
plt.show()
